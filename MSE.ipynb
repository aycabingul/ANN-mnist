# %%
Y = [1, 2, 1, 3] #tahmin edilen degerler
T = [1, 1, 2, 2] #gercek degerler

hata = 0
for i in range(len(Y)):
  hata = hata + (T[i] - Y[i])**2

MSE = hata/len(Y)

print("MSE=", MSE)
# Out:
# MSE= 0.75
